# %% [markdown]
# <a href="https://colab.research.google.com/github/iimam07/deep-learning-challenge/blob/main/AlphabetSoupCharity_Optimization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
fpath = "/content/gdrive/My Drive/charity_data.csv"
application_df = pd.read_csv(fpath)
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df.drop(['EIN', 'NAME'], axis=1, inplace=True)
application_df
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  \
# 0       Association       1              0                      N      5000
# 1      Co-operative       1         1-9999                      N    108590
# 2       Association       1              0                      N      5000
# 3             Trust       1    10000-24999                      N      6692
# 4             Trust       1  100000-499999                      N    142590
# ...             ...     ...            ...                    ...       ...
# 34294   Association       1              0                      N      5000
# 34295   Association       1              0                      N      5000
# 34296   Association       1              0                      N      5000
# 34297   Association       1              0                      N      5000
# 34298  Co-operative       1          1M-5M                      N  36500179
#
#        IS_SUCCESSFUL
# 0                  1
# 1                  1
# 2                  0
# 3                  1
# 4                  1
# ...              ...
# 34294              0
# 34295              0
# 34296              0
# 34297              1
# 34298              0
#
# [34299 rows x 10 columns]

# %%
# Determine the number of unique values in each column.
app_cat = application_df.dtypes.index.tolist()
application_df[app_cat].nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
app_type_count = application_df['APPLICATION_TYPE'].value_counts()
app_type_count
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = list(app_type_count[app_type_count < 600].index)

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# Other      804
# T8         737
# T7         725
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
class_count = application_df['CLASSIFICATION'].value_counts()
class_count.head(20)
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# Name: CLASSIFICATION, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
application_df['CLASSIFICATION'].value_counts().loc[lambda x : x >1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = list(class_count[class_count < 300].index)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# Other     1484
# C7000      777
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
numeric_app_df = pd.get_dummies(application_df)
numeric_app_df
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0           1      5000              1                       1
# 1           1    108590              1                       0
# 2           1      5000              0                       0
# 3           1      6692              1                       0
# 4           1    142590              1                       0
# ...       ...       ...            ...                     ...
# 34294       1      5000              0                       0
# 34295       1      5000              0                       0
# 34296       1      5000              0                       0
# 34297       1      5000              1                       0
# 34298       1  36500179              0                       0
#
#        APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  APPLICATION_TYPE_T4  \
# 0                         0                    0                    0
# 1                         0                    1                    0
# 2                         0                    0                    0
# 3                         0                    1                    0
# 4                         0                    1                    0
# ...                     ...                  ...                  ...
# 34294                     0                    0                    1
# 34295                     0                    0                    1
# 34296                     0                    1                    0
# 34297                     0                    0                    0
# 34298                     0                    1                    0
#
#        APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  APPLICATION_TYPE_T7  ...  \
# 0                        0                    0                    0  ...
# 1                        0                    0                    0  ...
# 2                        1                    0                    0  ...
# 3                        0                    0                    0  ...
# 4                        0                    0                    0  ...
# ...                    ...                  ...                  ...  ...
# 34294                    0                    0                    0  ...
# 34295                    0                    0                    0  ...
# 34296                    0                    0                    0  ...
# 34297                    1                    0                    0  ...
# 34298                    0                    0                    0  ...
#
#        INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0                      0                       0                         0
# 1                      1                       0                         0
# 2                      0                       0                         0
# 3                      0                       1                         0
# 4                      0                       0                         1
# ...                  ...                     ...                       ...
# 34294                  0                       0                         0
# 34295                  0                       0                         0
# 34296                  0                       0                         0
# 34297                  0                       0                         0
# 34298                  0                       0                         0
#
#        INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0                       0                 0                       0
# 1                       0                 0                       0
# 2                       0                 0                       0
# 3                       0                 0                       0
# 4                       0                 0                       0
# ...                   ...               ...                     ...
# 34294                   0                 0                       0
# 34295                   0                 0                       0
# 34296                   0                 0                       0
# 34297                   0                 0                       0
# 34298                   0                 1                       0
#
#        INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 0                    0                  0                         1
# 1                    0                  0                         1
# 2                    0                  0                         1
# 3                    0                  0                         1
# 4                    0                  0                         1
# ...                ...                ...                       ...
# 34294                0                  0                         1
# 34295                0                  0                         1
# 34296                0                  0                         1
# 34297                0                  0                         1
# 34298                0                  0                         1
#
#        SPECIAL_CONSIDERATIONS_Y
# 0                             0
# 1                             0
# 2                             0
# 3                             0
# 4                             0
# ...                         ...
# 34294                         0
# 34295                         0
# 34296                         0
# 34297                         0
# 34298                         0
#
# [34299 rows x 44 columns]

# %%
# Split our preprocessed data into our features and target arrays
y = numeric_app_df["IS_SUCCESSFUL"]
X = numeric_app_df.drop(["IS_SUCCESSFUL"],axis=1)

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Attempt 1
#
# 1.   List item
# 2.   List item

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len( X_train_scaled[0])
hidden_nodes_layer1=8
hidden_nodes_layer2=6
hidden_nodes_layer3=4

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation='relu'))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation='relu'))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation='relu'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 8)                 352
#
#  dense_1 (Dense)             (None, 6)                 54
#
#  dense_2 (Dense)             (None, 4)                 28
#
#  dense_3 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 439
# Trainable params: 439
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics=['accuracy'])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,validation_split=0.15, epochs=100)
# Out:
# Epoch 1/100
# 684/684 [==============================] - 6s 7ms/step - loss: 0.6294 - accuracy: 0.6673 - val_loss: 0.6036 - val_accuracy: 0.7113
# Epoch 2/100
# 684/684 [==============================] - 5s 7ms/step - loss: 0.5858 - accuracy: 0.7276 - val_loss: 0.5872 - val_accuracy: 0.7142
# Epoch 3/100
# 684/684 [==============================] - 3s 4ms/step - loss: 0.5735 - accuracy: 0.7287 - val_loss: 0.5782 - val_accuracy: 0.7181
# Epoch 4/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5656 - accuracy: 0.7306 - val_loss: 0.5723 - val_accuracy: 0.7194
# Epoch 5/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.5618 - accuracy: 0.7329 - val_loss: 0.5713 - val_accuracy: 0.7201
# Epoch 6/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.5590 - accuracy: 0.7326 - val_loss: 0.5688 - val_accuracy: 0.7212
# Epoch 7/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.5570 - accuracy: 0.7333 - val_loss: 0.5686 - val_accuracy: 0.7186
# Epoch 8/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.5557 - accuracy: 0.7328 - val_loss: 0.5680 - val_accuracy: 0.7178
# Epoch 9/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.5544 - accuracy: 0.7331 - val_loss: 0.5660 - val_accuracy: 0.7178
# Epoch 10/100
# 684/684 [==============================] - 2s 4ms/step - loss: 0.5539 - accuracy: 0.7339 - val_loss: 0.5660 - val_accuracy: 0.7186
# Epoch 11/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.5533 - accuracy: 0.7339 - val_loss: 0.5666 - val_accuracy: 0.7204
# Epoch 12/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5526 - accuracy: 0.7348 - val_loss: 0.5657 - val_accuracy: 0.7191
# Epoch 13/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5524 - accuracy: 0.7350 - val_loss: 0.5654 - val_accuracy: 0.7204
# Epoch 14/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.5514 - accuracy: 0.7346 - val_loss: 0.5658 - val_accuracy: 0.7230
# Epoch 15/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5516 - accuracy: 0.7356 - val_loss: 0.5640 - val_accuracy: 0.7217
# Epoch 16/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5511 - accuracy: 0.7348 - val_loss: 0.5651 - val_accuracy: 0.7212
# Epoch 17/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.5505 - accuracy: 0.7345 - val_loss: 0.5646 - val_accuracy: 0.7222
# Epoch 18/100
# 684/684 [==============================] - 2s 4ms/step - loss: 0.5504 - accuracy: 0.7346 - val_loss: 0.5635 - val_accuracy: 0.7219
# Epoch 19/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.5502 - accuracy: 0.7353 - val_loss: 0.5636 - val_accuracy: 0.7225
# Epoch 20/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5497 - accuracy: 0.7348 - val_loss: 0.5633 - val_accuracy: 0.7201
# Epoch 21/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5493 - accuracy: 0.7353 - val_loss: 0.5638 - val_accuracy: 0.7199
# Epoch 22/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5495 - accuracy: 0.7347 - val_loss: 0.5624 - val_accuracy: 0.7238
# Epoch 23/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.5490 - accuracy: 0.7354 - val_loss: 0.5641 - val_accuracy: 0.7222
# Epoch 24/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.5489 - accuracy: 0.7351 - val_loss: 0.5636 - val_accuracy: 0.7207
# Epoch 25/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.5489 - accuracy: 0.7355 - val_loss: 0.5628 - val_accuracy: 0.7212
# Epoch 26/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.5484 - accuracy: 0.7349 - val_loss: 0.5654 - val_accuracy: 0.7196
# Epoch 27/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5482 - accuracy: 0.7347 - val_loss: 0.5660 - val_accuracy: 0.7157
# Epoch 28/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5487 - accuracy: 0.7357 - val_loss: 0.5635 - val_accuracy: 0.7212
# Epoch 29/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5476 - accuracy: 0.7357 - val_loss: 0.5621 - val_accuracy: 0.7219
# Epoch 30/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5479 - accuracy: 0.7352 - val_loss: 0.5631 - val_accuracy: 0.7212
# Epoch 31/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5476 - accuracy: 0.7352 - val_loss: 0.5624 - val_accuracy: 0.7201
# Epoch 32/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5477 - accuracy: 0.7354 - val_loss: 0.5639 - val_accuracy: 0.7204
# Epoch 33/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.5476 - accuracy: 0.7347 - val_loss: 0.5643 - val_accuracy: 0.7201
# Epoch 34/100
# 684/684 [==============================] - 2s 4ms/step - loss: 0.5473 - accuracy: 0.7357 - val_loss: 0.5629 - val_accuracy: 0.7204
# Epoch 35/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.5472 - accuracy: 0.7366 - val_loss: 0.5641 - val_accuracy: 0.7170
# Epoch 36/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.5473 - accuracy: 0.7357 - val_loss: 0.5625 - val_accuracy: 0.7199
# Epoch 37/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.5469 - accuracy: 0.7358 - val_loss: 0.5626 - val_accuracy: 0.7191
# Epoch 38/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5470 - accuracy: 0.7346 - val_loss: 0.5632 - val_accuracy: 0.7194
# Epoch 39/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.5467 - accuracy: 0.7357 - val_loss: 0.5610 - val_accuracy: 0.7207
# Epoch 40/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.5464 - accuracy: 0.7361 - val_loss: 0.5644 - val_accuracy: 0.7222
# Epoch 41/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.5468 - accuracy: 0.7359 - val_loss: 0.5607 - val_accuracy: 0.7225
# Epoch 42/100
# 684/684 [==============================] - 2s 4ms/step - loss: 0.5462 - accuracy: 0.7359 - val_loss: 0.5618 - val_accuracy: 0.7219
# Epoch 43/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5462 - accuracy: 0.7348 - val_loss: 0.5641 - val_accuracy: 0.7214
# Epoch 44/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5463 - accuracy: 0.7362 - val_loss: 0.5615 - val_accuracy: 0.7194
# Epoch 45/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5459 - accuracy: 0.7358 - val_loss: 0.5621 - val_accuracy: 0.7201
# Epoch 46/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5459 - accuracy: 0.7359 - val_loss: 0.5625 - val_accuracy: 0.7201
# Epoch 47/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5458 - accuracy: 0.7363 - val_loss: 0.5616 - val_accuracy: 0.7191
# Epoch 48/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.5458 - accuracy: 0.7351 - val_loss: 0.5605 - val_accuracy: 0.7214
# Epoch 49/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.5454 - accuracy: 0.7356 - val_loss: 0.5606 - val_accuracy: 0.7238
# Epoch 50/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.5451 - accuracy: 0.7368 - val_loss: 0.5657 - val_accuracy: 0.7191
# Epoch 51/100
# 684/684 [==============================] - 2s 4ms/step - loss: 0.5451 - accuracy: 0.7370 - val_loss: 0.5616 - val_accuracy: 0.7219
# Epoch 52/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.5454 - accuracy: 0.7356 - val_loss: 0.5612 - val_accuracy: 0.7183
# Epoch 53/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5452 - accuracy: 0.7355 - val_loss: 0.5614 - val_accuracy: 0.7204
# Epoch 54/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5444 - accuracy: 0.7360 - val_loss: 0.5606 - val_accuracy: 0.7188
# Epoch 55/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.5446 - accuracy: 0.7363 - val_loss: 0.5605 - val_accuracy: 0.7225
# Epoch 56/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.5449 - accuracy: 0.7367 - val_loss: 0.5605 - val_accuracy: 0.7214
# Epoch 57/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.5445 - accuracy: 0.7365 - val_loss: 0.5612 - val_accuracy: 0.7217
# Epoch 58/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.5444 - accuracy: 0.7367 - val_loss: 0.5637 - val_accuracy: 0.7173
# Epoch 59/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5447 - accuracy: 0.7365 - val_loss: 0.5601 - val_accuracy: 0.7225
# Epoch 60/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5444 - accuracy: 0.7370 - val_loss: 0.5621 - val_accuracy: 0.7238
# Epoch 61/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5442 - accuracy: 0.7360 - val_loss: 0.5603 - val_accuracy: 0.7235
# Epoch 62/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5443 - accuracy: 0.7357 - val_loss: 0.5605 - val_accuracy: 0.7204
# Epoch 63/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5444 - accuracy: 0.7363 - val_loss: 0.5600 - val_accuracy: 0.7245
# Epoch 64/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.5441 - accuracy: 0.7373 - val_loss: 0.5601 - val_accuracy: 0.7230
# Epoch 65/100
# 684/684 [==============================] - 2s 4ms/step - loss: 0.5438 - accuracy: 0.7363 - val_loss: 0.5602 - val_accuracy: 0.7222
# Epoch 66/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.5444 - accuracy: 0.7363 - val_loss: 0.5612 - val_accuracy: 0.7217
# Epoch 67/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.5438 - accuracy: 0.7370 - val_loss: 0.5609 - val_accuracy: 0.7188
# Epoch 68/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5443 - accuracy: 0.7363 - val_loss: 0.5590 - val_accuracy: 0.7227
# Epoch 69/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5436 - accuracy: 0.7366 - val_loss: 0.5616 - val_accuracy: 0.7186
# Epoch 70/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5438 - accuracy: 0.7360 - val_loss: 0.5610 - val_accuracy: 0.7183
# Epoch 71/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5435 - accuracy: 0.7374 - val_loss: 0.5630 - val_accuracy: 0.7191
# Epoch 72/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.5437 - accuracy: 0.7370 - val_loss: 0.5607 - val_accuracy: 0.7219
# Epoch 73/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.5438 - accuracy: 0.7364 - val_loss: 0.5602 - val_accuracy: 0.7194
# Epoch 74/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.5434 - accuracy: 0.7373 - val_loss: 0.5592 - val_accuracy: 0.7199
# Epoch 75/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.5434 - accuracy: 0.7360 - val_loss: 0.5613 - val_accuracy: 0.7230
# Epoch 76/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5431 - accuracy: 0.7364 - val_loss: 0.5619 - val_accuracy: 0.7204
# Epoch 77/100
# 684/684 [==============================] - 2s 2ms/step - loss: 0.5428 - accuracy: 0.7367 - val_loss: 0.5608 - val_accuracy: 0.7199
# Epoch 78/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.5436 - accuracy: 0.7366 - val_loss: 0.5612 - val_accuracy: 0.7183
# Epoch 79/100
# 684/684 [==============================] - 3s 4ms/step - loss: 0.5431 - accuracy: 0.7369 - val_loss: 0.5641 - val_accuracy: 0.7155
# Epoch 80/100
# 684/684 [==============================] - 3s 4ms/step - loss: 0.5429 - accuracy: 0.7362 - val_loss: 0.5610 - val_accuracy: 0.7181
# Epoch 81/100
# 684/684 [==============================] - 2s 3ms/step - loss: 0.5428 - accuracy: 0.7370 - val_loss: 0.5604 - val_accuracy: 0.7173
# Epoch 82/100
# 663/684 [============================>.] - ETA: 0s - loss: 0.5431 - accuracy: 0.7373

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5560 - accuracy: 0.7264 - 762ms/epoch - 3ms/step
# Loss: 0.555995762348175, Accuracy: 0.7264139652252197

# %%
history_df = pd.DataFrame(fit_model.history, index = range(1, len(fit_model.history['loss'])+1))
history_df.plot(y = 'accuracy')
# Out:
# <Axes: >

# %%
# Export our model to HDF5 file
from google.colab import files

nn.save('alphabetsoupcharity_opt1.h5')
